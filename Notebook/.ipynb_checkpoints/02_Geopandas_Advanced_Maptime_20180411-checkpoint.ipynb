# %% [markdown]
# # Spatial Problem: In what cities will we be able to see upcoming eclipses?

# %% [markdown]
# First we need to import our libraries

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame

# new imports 
import os
data_pth = "../Data/"

# %% [markdown]
# Now to use some of our own data!

# %%
# Look in your Data directory to see this shapefile
eclipses = gpd.read_file(os.path.join(data_pth, "Eclipses.shp"))

# %%
eclipses.head()
# Out:
#    OID_                Name                                       FolderPath  \
# 0     0               Umbra    TSE 2017.08.21/TSE 2017 August 21 Umbral Path
# 1     0               Umbra      TSE 2019.07.02/TSE 2019 July 02 Umbral Path
# 2     0               Umbra  TSE 2020.12.14/TSE 2020 December 14 Umbral Path
# 3     0               Umbra  TSE 2021.12.04/TSE 2021 December 04 Umbral Path
# 4     0  Umbra Limit (East)     HSE 2023.04.20/HSE 2023 April 20 Umbral Path
#
#    SymbolID  AltMode  Base  Clamped  Extruded Snippet PopupInfo  Shape_Leng  \
# 0         0        0   0.0       -1         0    None      None  303.633219
# 1         0        0   0.0       -1         0    None      None  223.557661
# 2         0        0   0.0       -1         0    None      None  310.979509
# 3         0        0   0.0       -1         0    None      None  274.491359
# 4         0        0   0.0       -1         0    None      None  267.246357
#
#    Shape_Area  Year                                           geometry
# 0  130.461081  2017  POLYGON Z ((-171.57693 39.73810000000003 0, -1...
# 1  165.607105  2019  POLYGON Z ((-160.39845 -37.64846999999997 0, -...
# 2   99.233931  2020  POLYGON Z ((-132.81568 -7.773699999999963 0, -...
# 3  757.922577  2021  POLYGON Z ((-51.18286999999998 -53.08708999999...
# 4   31.230251  2023  POLYGON Z ((180.0000000000001 3.21677000000005...

# %%
# view it differently by transposing rows and columns
eclipses.head().T
# Out:
#                                                             0  \
# OID_                                                        0
# Name                                                    Umbra
# FolderPath      TSE 2017.08.21/TSE 2017 August 21 Umbral Path
# SymbolID                                                    0
# AltMode                                                     0
# Base                                                        0
# Clamped                                                    -1
# Extruded                                                    0
# Snippet                                                  None
# PopupInfo                                                None
# Shape_Leng                                            303.633
# Shape_Area                                            130.461
# Year                                                     2017
# geometry    POLYGON Z ((-171.57693 39.73810000000003 0, -1...
#
#                                                             1  \
# OID_                                                        0
# Name                                                    Umbra
# FolderPath        TSE 2019.07.02/TSE 2019 July 02 Umbral Path
# SymbolID                                                    0
# AltMode                                                     0
# Base                                                        0
# Clamped                                                    -1
# Extruded                                                    0
# Snippet                                                  None
# PopupInfo                                                None
# Shape_Leng                                            223.558
# Shape_Area                                            165.607
# Year                                                     2019
# geometry    POLYGON Z ((-160.39845 -37.64846999999997 0, -...
#
#                                                             2  \
# OID_                                                        0
# Name                                                    Umbra
# FolderPath    TSE 2020.12.14/TSE 2020 December 14 Umbral Path
# SymbolID                                                    0
# AltMode                                                     0
# Base                                                        0
# Clamped                                                    -1
# Extruded                                                    0
# Snippet                                                  None
# PopupInfo                                                None
# Shape_Leng                                             310.98
# Shape_Area                                            99.2339
# Year                                                     2020
# geometry    POLYGON Z ((-132.81568 -7.773699999999963 0, -...
#
#                                                             3  \
# OID_                                                        0
# Name                                                    Umbra
# FolderPath    TSE 2021.12.04/TSE 2021 December 04 Umbral Path
# SymbolID                                                    0
# AltMode                                                     0
# Base                                                        0
# Clamped                                                    -1
# Extruded                                                    0
# Snippet                                                  None
# PopupInfo                                                None
# Shape_Leng                                            274.491
# Shape_Area                                            757.923
# Year                                                     2021
# geometry    POLYGON Z ((-51.18286999999998 -53.08708999999...
#
#                                                             4
# OID_                                                        0
# Name                                       Umbra Limit (East)
# FolderPath       HSE 2023.04.20/HSE 2023 April 20 Umbral Path
# SymbolID                                                    0
# AltMode                                                     0
# Base                                                        0
# Clamped                                                    -1
# Extruded                                                    0
# Snippet                                                  None
# PopupInfo                                                None
# Shape_Leng                                            267.246
# Shape_Area                                            31.2303
# Year                                                     2023
# geometry    POLYGON Z ((180.0000000000001 3.21677000000005...

# %%
# Check the coordinate reference system of our data, its crs
eclipses.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# Now we plot
eclipses.plot()

# %%
# Examine what the envelope of our data looks like
eclipses.envelope.plot()

# %%
# Where exactly are these paths? Let's add our basemap to make this clear.
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
# Pass ax=ax to the second layer
eclipses.plot(ax=ax)
# There is an axis by default. You can see it if you comment out the below.
ax.set_axis_off()

# %%
# Let's load in the cities provided by geopandas. Note these are just the capitals.
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
# Now we'll plot our basemap, our eclipse paths, and our cities
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
eclipses.plot(ax=ax)
cities.plot(marker='*', color='yellow', markersize=5, ax=ax)
ax.axis('off')
# Out:
# (-198.0, 198.00000000000014, -98.95351100000003, 98.0237310000001)

# %%
# But we want MORE cities, so let's use our own. This is a local shapefile in your data directory.
cities = gpd.read_file(os.path.join(data_pth, "ne_10m_populated_places.shp"))

# %%
cities.head().T
# Out:
#                                                             0  \
# SCALERANK                                                  10
# NATSCALE                                                    1
# LABELRANK                                                   8
# FEATURECLA                                    Admin-1 capital
# NAME                                   Colonia del Sacramento
# NAMEPAR                                                  None
# NAMEALT                                                  None
# DIFFASCII                                                   0
# NAMEASCII                              Colonia del Sacramento
# ADM0CAP                                                     0
# CAPIN                                                    None
# WORLDCITY                                                   0
# MEGACITY                                                    0
# SOV0NAME                                              Uruguay
# SOV_A3                                                    URY
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                              Colonia
# ISO_A2                                                     UY
# NOTE                                                     None
# LATITUDE                                               -34.48
# LONGITUDE                                              -57.84
# CHANGED                                                     4
# NAMEDIFF                                                    1
# DIFFNOTE    Added missing admin-1 capital. Population from...
# POP_MAX                                                 21714
# POP_MIN                                                 21714
# POP_OTHER                                                   0
# RANK_MAX                                                    7
# RANK_MIN                                                    7
# ...                                                       ...
# POP1950                                                     0
# POP1955                                                     0
# POP1960                                                     0
# POP1965                                                     0
# POP1970                                                     0
# POP1975                                                     0
# POP1980                                                     0
# POP1985                                                     0
# POP1990                                                     0
# POP1995                                                     0
# POP2000                                                     0
# POP2005                                                     0
# POP2010                                                     0
# POP2015                                                     0
# POP2020                                                     0
# POP2025                                                     0
# POP2050                                                     0
# CITYALT                                                  None
# min_zoom                                                    9
# wikidataid                                             Q56064
# wof_id                                              421199749
# CAPALT                                                    NaN
# NAME_EN                                Colonia del Sacramento
# NAME_DE                                Colonia del Sacramento
# NAME_ES                                Colonia del Sacramento
# NAME_FR                                Colonia del Sacramento
# NAME_PT                                 Colônia do Sacramento
# NAME_RU                               Колония-дель-Сакраменто
# NAME_ZH                                           科洛尼亞德爾薩克拉門托
# geometry        POINT (-57.84000247340134 -34.47999900541754)
#
#                                                             1  \
# SCALERANK                                                  10
# NATSCALE                                                    1
# LABELRANK                                                   8
# FEATURECLA                                    Admin-1 capital
# NAME                                                 Trinidad
# NAMEPAR                                                  None
# NAMEALT                                                  None
# DIFFASCII                                                   0
# NAMEASCII                                            Trinidad
# ADM0CAP                                                     0
# CAPIN                                                    None
# WORLDCITY                                                   0
# MEGACITY                                                    0
# SOV0NAME                                              Uruguay
# SOV_A3                                                    URY
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                               Flores
# ISO_A2                                                     UY
# NOTE                                                     None
# LATITUDE                                              -33.544
# LONGITUDE                                             -56.901
# CHANGED                                                     4
# NAMEDIFF                                                    1
# DIFFNOTE    Added missing admin-1 capital. Population from...
# POP_MAX                                                 21093
# POP_MIN                                                 21093
# POP_OTHER                                                   0
# RANK_MAX                                                    7
# RANK_MIN                                                    7
# ...                                                       ...
# POP1950                                                     0
# POP1955                                                     0
# POP1960                                                     0
# POP1965                                                     0
# POP1970                                                     0
# POP1975                                                     0
# POP1980                                                     0
# POP1985                                                     0
# POP1990                                                     0
# POP1995                                                     0
# POP2000                                                     0
# POP2005                                                     0
# POP2010                                                     0
# POP2015                                                     0
# POP2020                                                     0
# POP2025                                                     0
# POP2050                                                     0
# CITYALT                                                  None
# min_zoom                                                    9
# wikidataid                                            Q862508
# wof_id                                              890444639
# CAPALT                                                    NaN
# NAME_EN                                              Trinidad
# NAME_DE                                              Trinidad
# NAME_ES                                              Trinidad
# NAME_FR                                              Trinidad
# NAME_PT                                              Trinidad
# NAME_RU                                              Тринидад
# NAME_ZH                                                  特立尼達
# geometry         POINT (-56.90099656015872 -33.5439989373607)
#
#                                                             2  \
# SCALERANK                                                  10
# NATSCALE                                                    1
# LABELRANK                                                   8
# FEATURECLA                                    Admin-1 capital
# NAME                                              Fray Bentos
# NAMEPAR                                                  None
# NAMEALT                                                  None
# DIFFASCII                                                   0
# NAMEASCII                                         Fray Bentos
# ADM0CAP                                                     0
# CAPIN                                                    None
# WORLDCITY                                                   0
# MEGACITY                                                    0
# SOV0NAME                                              Uruguay
# SOV_A3                                                    URY
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                            Río Negro
# ISO_A2                                                     UY
# NOTE                                                     None
# LATITUDE                                              -33.139
# LONGITUDE                                             -58.304
# CHANGED                                                     4
# NAMEDIFF                                                    1
# DIFFNOTE    Added missing admin-1 capital. Population from...
# POP_MAX                                                 23279
# POP_MIN                                                 23279
# POP_OTHER                                                   0
# RANK_MAX                                                    7
# RANK_MIN                                                    7
# ...                                                       ...
# POP1950                                                     0
# POP1955                                                     0
# POP1960                                                     0
# POP1965                                                     0
# POP1970                                                     0
# POP1975                                                     0
# POP1980                                                     0
# POP1985                                                     0
# POP1990                                                     0
# POP1995                                                     0
# POP2000                                                     0
# POP2005                                                     0
# POP2010                                                     0
# POP2015                                                     0
# POP2020                                                     0
# POP2025                                                     0
# POP2050                                                     0
# CITYALT                                                  None
# min_zoom                                                    9
# wikidataid                                            Q849835
# wof_id                                              890451703
# CAPALT                                                    NaN
# NAME_EN                                           Fray Bentos
# NAME_DE                                           Fray Bentos
# NAME_ES                                           Fray Bentos
# NAME_FR                                           Fray Bentos
# NAME_PT                                           Fray Bentos
# NAME_RU                                           Фрай-Бентос
# NAME_ZH                                                 弗賴本托斯
# geometry          POINT (-58.3039974719095 -33.1389990288435)
#
#                                                             3  \
# SCALERANK                                                  10
# NATSCALE                                                    1
# LABELRANK                                                   8
# FEATURECLA                                    Admin-1 capital
# NAME                                                Canelones
# NAMEPAR                                                  None
# NAMEALT                                                  None
# DIFFASCII                                                   0
# NAMEASCII                                           Canelones
# ADM0CAP                                                     0
# CAPIN                                                    None
# WORLDCITY                                                   0
# MEGACITY                                                    0
# SOV0NAME                                              Uruguay
# SOV_A3                                                    URY
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                            Canelones
# ISO_A2                                                     UY
# NOTE                                                     None
# LATITUDE                                              -34.538
# LONGITUDE                                             -56.284
# CHANGED                                                     4
# NAMEDIFF                                                    1
# DIFFNOTE    Added missing admin-1 capital. Population from...
# POP_MAX                                                 19698
# POP_MIN                                                 19698
# POP_OTHER                                                   0
# RANK_MAX                                                    6
# RANK_MIN                                                    6
# ...                                                       ...
# POP1950                                                     0
# POP1955                                                     0
# POP1960                                                     0
# POP1965                                                     0
# POP1970                                                     0
# POP1975                                                     0
# POP1980                                                     0
# POP1985                                                     0
# POP1990                                                     0
# POP1995                                                     0
# POP2000                                                     0
# POP2005                                                     0
# POP2010                                                     0
# POP2015                                                     0
# POP2020                                                     0
# POP2025                                                     0
# POP2050                                                     0
# CITYALT                                                  None
# min_zoom                                                    9
# wikidataid                                            Q841342
# wof_id                                              890444649
# CAPALT                                                    NaN
# NAME_EN                                             Canelones
# NAME_DE                                             Canelones
# NAME_ES                                             Canelones
# NAME_FR                                             Canelones
# NAME_PT                                             Canelones
# NAME_RU                                             Канелонес
# NAME_ZH                                                 卡內洛內斯
# geometry        POINT (-56.28400149324307 -34.53800400667546)
#
#                                                             4
# SCALERANK                                                  10
# NATSCALE                                                    1
# LABELRANK                                                   8
# FEATURECLA                                    Admin-1 capital
# NAME                                                  Florida
# NAMEPAR                                                  None
# NAMEALT                                                  None
# DIFFASCII                                                   0
# NAMEASCII                                             Florida
# ADM0CAP                                                     0
# CAPIN                                                    None
# WORLDCITY                                                   0
# MEGACITY                                                    0
# SOV0NAME                                              Uruguay
# SOV_A3                                                    URY
# ADM0NAME                                              Uruguay
# ADM0_A3                                                   URY
# ADM1NAME                                              Florida
# ISO_A2                                                     UY
# NOTE                                                     None
# LATITUDE                                              -34.099
# LONGITUDE                                             -56.215
# CHANGED                                                     4
# NAMEDIFF                                                    1
# DIFFNOTE    Added missing admin-1 capital. Population from...
# POP_MAX                                                 32234
# POP_MIN                                                 32234
# POP_OTHER                                                   0
# RANK_MAX                                                    7
# RANK_MIN                                                    7
# ...                                                       ...
# POP1950                                                     0
# POP1955                                                     0
# POP1960                                                     0
# POP1965                                                     0
# POP1970                                                     0
# POP1975                                                     0
# POP1980                                                     0
# POP1985                                                     0
# POP1990                                                     0
# POP1995                                                     0
# POP2000                                                     0
# POP2005                                                     0
# POP2010                                                     0
# POP2015                                                     0
# POP2020                                                     0
# POP2025                                                     0
# POP2050                                                     0
# CITYALT                                                  None
# min_zoom                                                    7
# wikidataid                                            Q842472
# wof_id                                              890431207
# CAPALT                                                    NaN
# NAME_EN                                               Florida
# NAME_DE                                               Florida
# NAME_ES                                               Florida
# NAME_FR                                               Florida
# NAME_PT                                               Florida
# NAME_RU                                               Флорида
# NAME_ZH                                                  佛羅里達
# geometry        POINT (-56.21499844799416 -34.09900200521719)
#
# [103 rows x 5 columns]

# %%
# Check the crs of our new cities data
cities.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# Is the cities data still in the same crs as the eclipse data? Let's check.
eclipses.crs == cities.crs
# Out:
# True

# %%
# Great. Let's plot it all again
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
eclipses.plot(ax=ax)
cities.plot(marker='*', color='yellow', markersize=5, ax=ax)
ax.axis('off')
# Out:
# (-198.38630091388413, 198.1796256180855, -99.64179619362255, 98.0565064854107)

# %%
# Let's change our eclipse colors and transparency
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
eclipses.plot(ax=ax, cmap='tab10', alpha=0.5)
cities.plot(marker='*', color='yellow', markersize=5, ax=ax)
ax.axis('off')
# Out:
# (-198.38630091388413, 198.1796256180855, -99.64179619362255, 98.0565064854107)

# %%
# We just want to focus on a single eclipse path for our analysis. We will select one by year.
print(eclipses['Year'])
# Out:
# 0     2017
# 1     2019
# 2     2020
# 3     2021
# 4     2023
# 5     2024
# 6     2026
# 7     2027
# 8     2028
# 9     2030
# 10    2031
# 11    2031
# 12    2033
# 13    2033
# 14    2033
# Name: Year, dtype: int64

# %%
# But how do we know which is which?
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))

# We added categorical, column, and legend properties
eclipses.plot(ax=ax, cmap='tab10', categorical=True, alpha=0.5, column = "Year", legend=True)
ax.axis('off')
# Out:
# (-198.0, 198.00000000000014, -98.95351100000003, 98.0237310000001)

# %% [markdown]
# Your turn #1: Select the eclipse that you want to focus on.

# %%
# Your code here

# %%
# I'll pick the one from 2017, it was on my birthday after all.
myeclipse = eclipses[(eclipses['Year'] == 2017)]

# %%
# Let's plot it 
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
myeclipse.plot(ax=ax)
cities.plot(marker='*', color='yellow', markersize=5, ax=ax)
ax.axis('off')
# Out:
# (-198.36062037118467, 198.1539450753859, -99.34968948168924, 92.3591690229376)

# %%
# But I want to zoom in on my chosen eclipse path
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
myeclipse.plot(ax=ax)
cities.plot(marker='*', color='yellow', markersize=5, ax=ax)
bounds = myeclipse.geometry.bounds

# To do this, you set the bounds to the min/max x/y of your layer
plt.xlim([bounds.minx.min()-5, bounds.maxx.max()+5])
plt.ylim([bounds.miny.min()-5, bounds.maxy.max()+5])
# Out:
# (5.781950000000052, 50.365410000000054)

# %%
# Let's style the plot so that the eclipse looks eclipse-ier
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
myeclipse.plot(ax=ax, color='yellow', edgecolor='black', alpha=0.5)
cities.plot(marker='o', color='black', markersize=2, ax=ax, alpha=0.5)
bounds = myeclipse.geometry.bounds
plt.xlim([bounds.minx.min()-5, bounds.maxx.max()+5])
plt.ylim([bounds.miny.min()-5, bounds.maxy.max()+5])
# Out:
# (5.781950000000052, 50.365410000000054)

# %%
# Check that the crs are the same for myeclipse and cities
print('data is in the same crs:', myeclipse.crs == cities.crs, ':', myeclipse.crs)
# Out:
# data is in the same crs: True : {'init': 'epsg:4326'}

# %%
# We can see that there are a few cities that intersect my path! But we want to know which ones.
# Do a spatial join to get the intersection
from geopandas.tools import sjoin
ecities = gpd.sjoin(cities, myeclipse, how='inner', op='intersects')
ecities.head()
# Out:
#      SCALERANK  NATSCALE  LABELRANK       FEATURECLA          NAME NAMEPAR  \
# 625          8        10          1  Populated place       Ontario    None
# 629          8        10          1  Populated place        Lander    None
# 637          8        10          1  Populated place   Kansas City    None
# 643          8        10          1  Populated place  Independence    None
# 645          8        10          1  Populated place       Kearney    None
#
#     NAMEALT  DIFFASCII     NAMEASCII  ADM0CAP  ...  SymbolID  AltMode  Base  \
# 625    None          0       Ontario      0.0  ...         0        0   0.0
# 629    None          0        Lander      0.0  ...         0        0   0.0
# 637    None          0   Kansas City      0.0  ...         0        0   0.0
# 643    None          0  Independence      0.0  ...         0        0   0.0
# 645    None          0       Kearney      0.0  ...         0        0   0.0
#
#     Clamped Extruded Snippet PopupInfo  Shape_Leng  Shape_Area  Year
# 625      -1        0    None      None  303.633219  130.461081  2017
# 629      -1        0    None      None  303.633219  130.461081  2017
# 637      -1        0    None      None  303.633219  130.461081  2017
# 643      -1        0    None      None  303.633219  130.461081  2017
# 645      -1        0    None      None  303.633219  130.461081  2017
#
# [5 rows x 117 columns]

# %%
# Let's plot the results!
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
myeclipse.plot(ax=ax, color='yellow', edgecolor='black', alpha=0.5)
ecities.plot(marker='*', color='black', markersize=5, ax=ax)
bounds = myeclipse.geometry.bounds
plt.xlim([bounds.minx.min()-5, bounds.maxx.max()+5])
plt.ylim([bounds.miny.min()-5, bounds.maxy.max()+5])
# Out:
# (5.781950000000052, 50.365410000000054)

# %%
print('Wow! There are {} cities in your path!'.format(len(ecities)))
print()
print(ecities['NAME'])
# Out:
# Wow! There are 39 cities in your path!
#
# 625            Ontario
# 629             Lander
# 637        Kansas City
# 643       Independence
# 645            Kearney
# 646       Grand Island
# 647           Alliance
# 716         Orangeburg
# 719     Cape Girardeau
# 731       Hopkinsville
# 733       Madisonville
# 1882          John Day
# 1884         Corvallis
# 1885            Albany
# 1898           Douglas
# 1899          Riverton
# 1900       Thermopolis
# 1925          Columbia
# 1926        St. Joseph
# 1929      North Platte
# 1931       Scottsbluff
# 2010        Greenville
# 2011            Sumter
# 2012          Anderson
# 2024        Carbondale
# 2032     Bowling Green
# 2033           Paducah
# 2045         Oak Ridge
# 2046      Murfreesboro
# 2047       Clarksville
# 4888    Jefferson City
# 5386       Idaho Falls
# 5404           Lincoln
# 5423        Charleston
# 6226             Salem
# 6227            Casper
# 6229       Kansas City
# 6247          Columbia
# 6795         Nashville
# Name: NAME, dtype: object

# %% [markdown]
# # Make it slippy

# %%
import folium

# %%
# Let's find the centroid of the eclipse we chose, so that we can center our folum map on it
x = myeclipse.centroid.x.values[0]
y = myeclipse.centroid.y.values[0]
print('y: ' + str(y) + ', x: ' + str(x))

# Note: results will vary depending on the eclipse you chose
# Out:
# y: 34.49685026675363, x: -97.05319819003572

# %% [markdown]
# Let's choose a basemap! There are many options, [check them out](https://deparkes.co.uk/2016/06/10/folium-map-tiles/).

# %%
# Note: no matter what projection you were in before, the folium maps will be in Web Mercator
map_osm = folium.Map(location=[y, x], zoom_start=3)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_carto = folium.Map(
    location=[y, x],
    tiles='Cartodb Positron',
    zoom_start=3
)
map_carto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_stamen = folium.Map(
    location=[y, x],
    tiles='stamenwatercolor',
    zoom_start=3
)
map_stamen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.GeoJson(ecities,name='Eclipse Cities').add_to(map_stamen)
folium.GeoJson(myeclipse,name='Eclipse Path').add_to(map_stamen)

# Add a layer control if you like
#folium.LayerControl().add_to(map_stamen)

map_stamen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Saving your results as a Esri Shapefile is easy with GeoPandas
myeclipse.to_file('../Data/myeclipse.shp', driver='ESRI Shapefile')
ecities.to_file('../Data/ecities.shp', driver='ESRI Shapefile')

# %% [markdown]
# # Are any eclipses passing over Cleveland?

# %%
cleveland = cities.loc[cities['NAME'] == 'Cleveland']
cleveland
# Out:
#             SCALERANK  NATSCALE  LABELRANK       FEATURECLA       NAME  \
# index_left
# 6793                3       110          1  Populated place  Cleveland
#
#            NAMEPAR NAMEALT  DIFFASCII  NAMEASCII  ADM0CAP  \
# index_left
# 6793          None    None          0  Cleveland      0.0
#
#                                 ...                          wof_id  CAPALT  \
# index_left                      ...
# 6793                            ...                       101712563     NaN
#
#               NAME_EN    NAME_DE    NAME_ES    NAME_FR    NAME_PT   NAME_RU  \
# index_left
# 6793        Cleveland  Cleveland  Cleveland  Cleveland  Cleveland  Кливленд
#
#            NAME_ZH                                      geometry
# index_left
# 6793          克里夫蘭  POINT (-81.69694406998963 41.47193265371732)
#
# [1 rows x 103 columns]

# %%
ecleve = gpd.sjoin(cleveland, eclipses, how='inner', op='intersects')
print('{} eclipse(s) will pass through Cleveland in the year(s) {}'.format(len(ecleve), int(ecleve['Year'])))
# Out:
# 1 eclipse(s) will pass through Cleveland in the year(s) 2024

# %%
cleveland_eclipse = eclipses.loc[eclipses['Year'] == int(ecleve['Year'])]

# %%
# plot it!
ax = world.plot(color='lightgrey', linewidth=0.5, edgecolor='white', figsize=(15,5))
cleveland_eclipse.plot(ax=ax, color='yellow', edgecolor='black', alpha=0.5)
cleveland.plot(marker='*', color='red', markersize=500, ax=ax)
bounds = cleveland_eclipse.geometry.bounds
plt.xlim([bounds.minx.min()-5, bounds.maxx.max()+5])
plt.ylim([bounds.miny.min()-5, bounds.maxy.max()+5])
# Out:
# (-13.450309999999945, 54.82445000000007)

# %%
## TO DO
# How many will pass over the city where you live?

# %%
# Plot it, if applicable

# %%
# Plot it on a slippy map, if applicable

# %%
seattle = cities.loc[cities['NAME'] == 'Seattle']
seattle
# Out:
#             SCALERANK  NATSCALE  LABELRANK       FEATURECLA     NAME NAMEPAR  \
# index_left
# 7108                2       200          1  Populated place  Seattle    None
#
#            NAMEALT  DIFFASCII NAMEASCII  ADM0CAP  \
# index_left
# 7108          None          0   Seattle      0.0
#
#                                 ...                          wof_id  CAPALT  \
# index_left                      ...
# 7108                            ...                       101730401     NaN
#
#             NAME_EN  NAME_DE  NAME_ES  NAME_FR  NAME_PT NAME_RU NAME_ZH  \
# index_left
# 7108        Seattle  Seattle  Seattle  Seattle  Seattle   Сиэтл     西雅圖
#
#                                                 geometry
# index_left
# 7108        POINT (-122.3419308458685 47.57194791253073)
#
# [1 rows x 103 columns]

# %%
eseattle = gpd.sjoin(seattle, eclipses, how='inner', op='intersects')
print('There are {} eclipses passing through Seattle!'.format(len(ecleve)))
# Out:
# There are 1 eclipses passing through Seattle!

# %% [markdown]
# I guess not. But which one is closest?

# %% [markdown]
# # Which eclipse will cover the largest population?

# %% [markdown]
# To Fix:
# * Move legend off the map
#
# To Add:
#
# * Are any eclipses passing over Cleveland?
# * If not, which is closest?
# * How far is it?, What else can we look at?
# * Which eclipse is most likely to have clear skies? (may need date and/or season data)
# * Find the eclipse that will cover the largest population
